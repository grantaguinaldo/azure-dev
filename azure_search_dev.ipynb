# %%
import json
import requests as r
from auth_key import *

#Connection String Builder
endpoint = 'https://myapi.search.windows.net/'
api_version = 'docs?api-version=2019-05-06'
index = "indexes/azureblob-index-aqmdrule-search/"

search_term = "&search=boiler&top=1&highlight=content"

url = endpoint + index + api_version + search_term

#API Call
response  = r.get(url, headers=headers)
index_list = response.json()
index_list['value'][0]["keyphrases"]
# Out:
# ['chemical heat',
#  'Btu',
#  'total heat input',
#  'ANNUAL HEAT INPUT',
#  'rated heat input capacity',
#  'hour',
#  'British thermal unit',
#  'sensible heat of incoming combustion air',
#  'ADSORPTION CHILLER UNIT',
#  'combustion gases',
#  'unfired waste heat recovery boiler',
#  'combustion of fuel',
#  'combustion equipment',
#  'thermal fluid heaters',
#  'natural gas',
#  'combustion turbine',
#  'STEAM GENERATORS',
#  'process heaters of equal',
#  'landfill gases',
#  'digester gas',
#  'capacity greater',
#  'TUBE BOILER',
#  'non-sealed combustion',
#  'schools',
#  'atmospheric units',
#  'hot gases',
#  'universities greater',
#  'exhaust',
#  'GROUP',
#  'RULE',
#  'natural draft',
#  'gaseous fuels',
#  'cold water',
#  'INDUSTRIAL OPERATION',
#  'HEALTH FACILITY',
#  'sealed container of water',
#  'air conditioning',
#  'BOILERS',
#  'process requirements',
#  'commercial operations',
#  'fossil fuel',
#  'tubes',
#  'California Health',
# ...

# %%
#https://docs.microsoft.com/en-us/azure/search/search-get-started-python
